# %%
import pandas as pd
import subprocess
import os
import sys
import shutil
from Bio import SeqIO

# --- Configuration ---
INPUT_CSV = 'thermoproteota_data.csv'
OUTPUT_DIR = 'fastpart_results'
TRAIN_OUTPUT_CSV = 'thermoproteota_train.csv'
TEST_OUTPUT_CSV = 'thermoproteota_test.csv'

# Parameters (Must match what you want to run)
IDENTITY_THRESHOLD = 0.3  
TRAIN_RATIO = 0.8         
METHOD = 'mmseq'          

def step_1_prepare_input(csv_path, fasta_path):
    print(f"[1/4] Reading and preparing {csv_path}...")
    try:
        df = pd.read_csv(csv_path)
    except Exception as e:
        print(f"Error reading CSV: {e}")
        sys.exit(1)

    # Deduplicate to ensure clean processing
    df_clean = df.drop_duplicates(subset=['Entry']).copy()
    print(f"      Unique sequences to process: {len(df_clean)}")

    with open(fasta_path, 'w') as f_out:
        for _, row in df_clean.iterrows():
            seq_id = str(row['Entry']).strip().replace('|', '_')
            label = "global" 
            sequence = str(row['Sequence']).strip()
            f_out.write(f">{seq_id}|{label}\n{sequence}\n")
    
    return df_clean

def step_2_run_buggy_tool(fasta_path, out_dir):
    print(f"\n[2/4] Running fast_part.py (Output Train.fasta will break, this is expected)...")
    
    if os.path.exists(out_dir):
        shutil.rmtree(out_dir)

    # We assume fast_part.py is in the current directory
    cmd = [
        "python", "fast_part.py",
        "--fasta_file", fasta_path,
        "--output_dir", out_dir,
        "--method", METHOD,
        "--identity_threshold", str(IDENTITY_THRESHOLD),
        "--train_ratio", str(TRAIN_RATIO)
    ]

    try:
        subprocess.run(cmd, check=True)
    except subprocess.CalledProcessError:
        print("Error running fast_part.py")
        sys.exit(1)

def step_3_reconstruct_data(original_df, out_dir):
    print(f"\n[3/4] Reconstructing lost Training Data...")

    # 1. Get Test IDs (These are safe)
    test_fasta = os.path.join(out_dir, "Test.fasta")
    if not os.path.exists(test_fasta):
        print("CRITICAL: Test.fasta not found. The tool failed completely.")
        sys.exit(1)
        
    test_ids = set()
    for record in SeqIO.parse(test_fasta, "fasta"):
        test_ids.add(record.id.split('|')[0])
    
    # 2. Get Removed IDs (From Summary Log)
    summary_file = os.path.join(out_dir, "summary.txt")
    removed_ids = set()
    if os.path.exists(summary_file):
        with open(summary_file, 'r') as f:
            is_reading_ids = False
            for line in f:
                line = line.strip()
                if line == "Removed sequence IDs:":
                    is_reading_ids = True
                    continue
                if is_reading_ids and line:
                    # IDs in summary are just the ID (e.g., A0A510E346)
                    removed_ids.add(line)
    
    print(f"      Test Set Size:     {len(test_ids)}")
    print(f"      Removed Sequences: {len(removed_ids)}")

    # 3. Calculate Train IDs
    # Train = All - Test - Removed
    all_ids = set(original_df['Entry'].astype(str))
    
    # Filter valid Train IDs
    train_ids = all_ids - test_ids - removed_ids
    
    print(f"      Recovered Train Size: {len(train_ids)}")

    if len(train_ids) < 100:
        print("WARNING: Recovered Train set is still very small. Check threshold settings.")

    # 4. Create DataFrames
    test_df = original_df[original_df['Entry'].isin(test_ids)]
    train_df = original_df[original_df['Entry'].isin(train_ids)]
    
    return train_df, test_df

def step_4_save_outputs(train_df, test_df):
    print(f"\n[4/4] Saving final corrected CSVs...")
    train_df.to_csv(TRAIN_OUTPUT_CSV, index=False)
    test_df.to_csv(TEST_OUTPUT_CSV, index=False)
    print(f"      Success! Saved {TRAIN_OUTPUT_CSV} ({len(train_df)} rows)")
    print(f"      Success! Saved {TEST_OUTPUT_CSV} ({len(test_df)} rows)")

if __name__ == "__main__":
    if shutil.which("mmseqs") is None:
        print("Error: mmseqs not found in PATH.")
        sys.exit(1)

    if os.path.exists(INPUT_CSV):
        # Temp fasta for input
        temp_input = "temp_input_for_tool.fasta"
        
        # 1. Prepare
        df_clean = step_1_prepare_input(INPUT_CSV, temp_input)
        
        # 2. Run Tool (Let it fail on the file write)
        step_2_run_buggy_tool(temp_input, OUTPUT_DIR)
        
        # 3. Recover Data
        train_df, test_df = step_3_reconstruct_data(df_clean, OUTPUT_DIR)
        
        # 4. Save
        step_4_save_outputs(train_df, test_df)
        
        # Cleanup
        if os.path.exists(temp_input):
            os.remove(temp_input)
    else:
        print(f"Error: {INPUT_CSV} not found.")
# Out:
# [1/4] Reading and preparing thermoproteota_data.csv...
#       Unique sequences to process: 180810
#
# [2/4] Running fast_part.py (Output Train.fasta will break, this is expected)...
# createdb fastpart_results/global/global.fasta fastpart_results/Temp/global_mmseq_db
#
# MMseqs Version:                    	18.8cc5c
# Database type                      	0
# Shuffle input database             	true
# Createdb mode                      	0
# Write lookup file                  	1
# Offset of numeric ids              	0
# Threads                            	8
# Compressed                         	0
# Mask residues                      	0
# Mask residues probability          	0.9
# Mask lower case residues           	0
# Mask lower letter repeating N times	0
# Use GPU                            	0
# Verbosity                          	3
#
# Converting sequences
# [==================
# Time for merging to global_mmseq_db_h: 0h 0m 0s 21ms
# Time for merging to global_mmseq_db: 0h 0m 0s 43ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 316ms
# cluster fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_cluster fastpart_results/global/tmp --min-seq-id 0.3 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	18.8cc5c
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# Target search mode                  	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias scale            	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Mask lower letter repeating N times 	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	8
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.3
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Weight file name
# Cluster Weight threshold            	0.9
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 5.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 3
# linclust fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/16796507305602055742/clu_redundancy fastpart_results/global/tmp/16796507305602055742/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.3 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# kmermatcher fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.3 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Database size: 180810 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 180.81K 0s 276ms
# Sort kmer 0h 0m 0s 79ms
# Sort by rep. sequence 0h 0m 0s 41ms
# Time for fill: 0h 0m 0s 26ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 492ms
# rescorediagonal fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 180.81K 0s 102ms
# Time for merging to pref_rescore1: 0h 0m 0s 33ms
# Time for processing: 0h 0m 0s 162ms
# clust fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref_rescore1 fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 40ms
#
# Size of the sequence database: 180810
# Size of the alignment database: 180810
# Number of clusters: 60895
#
# Writing results 0h 0m 0s 8ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 64ms
# createsubdb fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/order_redundancy fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 17ms
# createsubdb fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/order_redundancy fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 18ms
# filterdb fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref_filter1 fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref_filter2 --filter-file fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/order_redundancy --threads 8 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 60.90K 0s 16ms
# Time for merging to pref_filter2: 0h 0m 0s 10ms
# Time for processing: 0h 0m 0s 44ms
# rescorediagonal fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref_filter2 fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 60.90K 0s 15ms
# Time for merging to pref_rescore2: 0h 0m 0s 10ms
# Time for processing: 0h 0m 0s 38ms
# align fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pref_rescore2 fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 60895 type: Aminoacid
# Target database size: 60895 type: Aminoacid
# Calculation of alignments
# [=================================================================] 60.90K 4s 678ms
# Time for merging to aln: 0h 0m 0s 12ms
# 96442 alignments calculated
# 92552 sequence pairs passed the thresholds (0.959665 of overall calculated)
# 1.519862 hits per query sequence
# Time for processing: 0h 0m 4s 706ms
# clust fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/aln fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 9ms
#
# Size of the sequence database: 60895
# Size of the alignment database: 60895
# Number of clusters: 43132
#
# Writing results 0h 0m 0s 5ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 21ms
# mergeclusters fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/16796507305602055742/clu_redundancy fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/pre_clust fastpart_results/global/tmp/16796507305602055742/linclust/16789789830740882543/clust --threads 8 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 60.90K 0s 6ms
# Clustering step 2
# [=================================================================] 43.13K 0s 10ms
# Write merged clustering
# [=================================================================] 180.81K 0s 20ms
# Time for merging to clu_redundancy: 0h 0m 0s 9ms
# Time for processing: 0h 0m 0s 47ms
# createsubdb fastpart_results/global/tmp/16796507305602055742/clu_redundancy fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/16796507305602055742/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 16ms
# prefilter fastpart_results/global/tmp/16796507305602055742/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3
#
# Query database size: 43132 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 43132 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 43.13K 0s 233ms
# Index table: Masked residues: 71591
# Index table: fill
# [=================================================================] 43.13K 0s 129ms
# Index statistics
# Entries:          4103461
# DB size:          511 MB
# Avg k-mer size:   0.064117
# Top 10 k-mers
#     GPGGTL	225
#     FGLDGR	49
#     GPGGSL	45
#     GPGGTT	45
#     NGGTLR	43
#     GLGNGK	38
#     LIGPGK	34
#     YTGTPK	32
#     GRGGTL	32
#     VHDKNI	31
# Time for index table init: 0h 0m 0s 585ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 43132
# Target db start 1 to 43132
# [=================================================================] 43.13K 0s 347ms
#
# 1.380077 k-mers per position
# 152 DB matches per sequence
# 0 overflows
# 3 sequences passed prefiltering per query sequence
# 2 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 8ms
# Time for processing: 0h 0m 1s 477ms
# align fastpart_results/global/tmp/16796507305602055742/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/pref_step0 fastpart_results/global/tmp/16796507305602055742/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 43132 type: Aminoacid
# Target database size: 43132 type: Aminoacid
# Calculation of alignments
# [=================================================================] 43.13K 8s 901ms
# Time for merging to aln_step0: 0h 0m 0s 9ms
# 143038 alignments calculated
# 124162 sequence pairs passed the thresholds (0.868035 of overall calculated)
# 2.878652 hits per query sequence
# Time for processing: 0h 0m 8s 924ms
# clust fastpart_results/global/tmp/16796507305602055742/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/aln_step0 fastpart_results/global/tmp/16796507305602055742/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 9ms
#
# Size of the sequence database: 43132
# Size of the alignment database: 43132
# Number of clusters: 27143
#
# Writing results 0h 0m 0s 3ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 18ms
# createsubdb fastpart_results/global/tmp/16796507305602055742/clu_step0 fastpart_results/global/tmp/16796507305602055742/input_step_redundancy fastpart_results/global/tmp/16796507305602055742/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 8ms
# prefilter fastpart_results/global/tmp/16796507305602055742/input_step1 fastpart_results/global/tmp/16796507305602055742/input_step1 fastpart_results/global/tmp/16796507305602055742/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3
#
# Query database size: 27143 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 27143 type: Aminoacid
# Index table k-mer threshold: 136 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 27.14K 0s 215ms
# Index table: Masked residues: 49820
# Index table: fill
# [=================================================================] 27.14K 0s 161ms
# Index statistics
# Entries:          5321804
# DB size:          518 MB
# Avg k-mer size:   0.083153
# Top 10 k-mers
#     GPGGTL	70
#     GKTLIA	25
#     AVGGGL	21
#     LGNATT	21
#     LELERR	20
#     GKTALA	19
#     LVGPGK	19
#     LLGPGK	18
#     LIGGGL	18
#     LKLEKE	17
# Time for index table init: 0h 0m 0s 651ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 136
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 27143
# Target db start 1 to 27143
# [=================================================================] 27.14K 1s 186ms
#
# 16.214477 k-mers per position
# 513 DB matches per sequence
# 0 overflows
# 4 sequences passed prefiltering per query sequence
# 3 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 6ms
# Time for processing: 0h 0m 2s 353ms
# align fastpart_results/global/tmp/16796507305602055742/input_step1 fastpart_results/global/tmp/16796507305602055742/input_step1 fastpart_results/global/tmp/16796507305602055742/pref_step1 fastpart_results/global/tmp/16796507305602055742/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 27143 type: Aminoacid
# Target database size: 27143 type: Aminoacid
# Calculation of alignments
# [=================================================================] 27.14K 2s 409ms
# Time for merging to aln_step1: 0h 0m 0s 5ms
# 103399 alignments calculated
# 49909 sequence pairs passed the thresholds (0.482684 of overall calculated)
# 1.838743 hits per query sequence
# Time for processing: 0h 0m 2s 432ms
# clust fastpart_results/global/tmp/16796507305602055742/input_step1 fastpart_results/global/tmp/16796507305602055742/aln_step1 fastpart_results/global/tmp/16796507305602055742/clu_step1 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 5ms
#
# Size of the sequence database: 27143
# Size of the alignment database: 27143
# Number of clusters: 20224
#
# Writing results 0h 0m 0s 2ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 11ms
# createsubdb fastpart_results/global/tmp/16796507305602055742/clu_step1 fastpart_results/global/tmp/16796507305602055742/input_step1 fastpart_results/global/tmp/16796507305602055742/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 6ms
# prefilter fastpart_results/global/tmp/16796507305602055742/input_step2 fastpart_results/global/tmp/16796507305602055742/input_step2 fastpart_results/global/tmp/16796507305602055742/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 5 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3
#
# Query database size: 20224 type: Aminoacid
# Estimated memory consumption: 1016M
# Target database size: 20224 type: Aminoacid
# Index table k-mer threshold: 118 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 20.22K 0s 218ms
# Index table: Masked residues: 39684
# Index table: fill
# [=================================================================] 20.22K 0s 113ms
# Index statistics
# Entries:          4269119
# DB size:          512 MB
# Avg k-mer size:   0.066705
# Top 10 k-mers
#     GPGGTL	30
#     LLLLLL	28
#     ALAAAA	23
#     LAAALA	22
#     LAALLA	21
#     LAAAAA	20
#     LAAAAL	20
#     ALAAAL	20
#     LAAALL	20
#     AALAAA	19
# Time for index table init: 0h 0m 0s 568ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 118
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 20224
# Target db start 1 to 20224
# [=================================================================] 20.22K 3s 369ms
#
# 129.872423 k-mers per position
# 2556 DB matches per sequence
# 0 overflows
# 13 sequences passed prefiltering per query sequence
# 15 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 6ms
# Time for processing: 0h 0m 4s 453ms
# align fastpart_results/global/tmp/16796507305602055742/input_step2 fastpart_results/global/tmp/16796507305602055742/input_step2 fastpart_results/global/tmp/16796507305602055742/pref_step2 fastpart_results/global/tmp/16796507305602055742/aln_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 20224 type: Aminoacid
# Target database size: 20224 type: Aminoacid
# Calculation of alignments
# [=================================================================] 20.22K 2s 83ms
# Time for merging to aln_step2: 0h 0m 0s 4ms
# 199614 alignments calculated
# 28078 sequence pairs passed the thresholds (0.140661 of overall calculated)
# 1.388350 hits per query sequence
# Time for processing: 0h 0m 2s 97ms
# clust fastpart_results/global/tmp/16796507305602055742/input_step2 fastpart_results/global/tmp/16796507305602055742/aln_step2 fastpart_results/global/tmp/16796507305602055742/clu_step2 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 3ms
#
# Size of the sequence database: 20224
# Size of the alignment database: 20224
# Number of clusters: 17053
#
# Writing results 0h 0m 0s 1ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 8ms
# mergeclusters fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_cluster fastpart_results/global/tmp/16796507305602055742/clu_redundancy fastpart_results/global/tmp/16796507305602055742/clu_step0 fastpart_results/global/tmp/16796507305602055742/clu_step1 fastpart_results/global/tmp/16796507305602055742/clu_step2 --threads 8 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 43.13K 0s 6ms
# Clustering step 2
# [=================================================================] 27.14K 0s 10ms
# Clustering step 3
# [=================================================================] 20.22K 0s 12ms
# Clustering step 4
# [=================================================================] 17.05K 0s 13ms
# Write merged clustering
# [=================================================================] 180.81K 0s 23ms
# Time for merging to global_mmseq_cluster: 0h 0m 0s 4ms
# Time for processing: 0h 0m 0s 48ms
# createtsv fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_cluster fastpart_results/Temp/global_mmseq.tsv
#
# MMseqs Version:                 	18.8cc5c
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	8
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to global_mmseq.tsv: 0h 0m 0s 6ms
# Time for processing: 0h 0m 0s 37ms
# diamond v2.1.16.170 (C) Max Planck Society for the Advancement of Science, Benjamin J. Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 8
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database input file: fastpart_results/Temp/train.fasta
# Opening the database file...  [0.001s]
# Loading sequences...  [0.347s]
# Masking sequences...  [0.292s]
# Writing sequences...  [0.016s]
# Hashing sequences...  [0.011s]
# Loading sequences...  [0s]
# Writing trailer...  [0s]
# Closing the input file...  [0s]
# Closing the database file...  [0s]
#
# Database sequences  144649
#   Database letters  39770421
#      Database hash  4d4ba6b53a47d0b34357913da8683d0c
#         Total time  0.669000s
# diamond v2.1.16.170 (C) Max Planck Society for the Advancement of Science, Benjamin J. Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 8
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database input file: fastpart_results/Train.fasta
# Opening the database file...  [0.001s]
# Loading sequences...  [0.348s]
# Masking sequences...  [0.295s]
# Writing sequences...  [0.02s]
# Hashing sequences...  [0.011s]
# Loading sequences...  [0s]
# Writing trailer...  [0s]
# Closing the input file...  [0s]
# Closing the database file...  [0s]
#
# Database sequences  144649
#   Database letters  39770421
#      Database hash  4d4ba6b53a47d0b34357913da8683d0c
#         Total time  0.677000s
# Updated combined train file is saved to fastpart_results/Train.fasta
# Updated combined test file is saved to fastpart_results/Test.fasta
# Summary file is saved to fastpart_results/summary.txt
# Execution time: 49.90 seconds
#
# [3/4] Reconstructing lost Training Data...
#       Test Set Size:     36161
#       Removed Sequences: 11168
#       Recovered Train Size: 133486
#
# [4/4] Saving final corrected CSVs...
#       Success! Saved thermoproteota_train.csv (133486 rows)
#       Success! Saved thermoproteota_test.csv (36161 rows)
