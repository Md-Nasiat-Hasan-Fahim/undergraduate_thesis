# %%
import pandas as pd
import subprocess
import os
import sys
import shutil
from Bio import SeqIO

# --- Configuration ---
INPUT_CSV = 'halobacteriales_data.csv'
OUTPUT_DIR = 'fastpart_results'
TRAIN_OUTPUT_CSV = 'halobacteriales_train.csv'
TEST_OUTPUT_CSV = 'halobacteriales_test.csv'

# Parameters (Must match what you want to run)
IDENTITY_THRESHOLD = 0.3  
TRAIN_RATIO = 0.8         
METHOD = 'mmseq'          

def step_1_prepare_input(csv_path, fasta_path):
    print(f"[1/4] Reading and preparing {csv_path}...")
    try:
        df = pd.read_csv(csv_path)
    except Exception as e:
        print(f"Error reading CSV: {e}")
        sys.exit(1)

    # Deduplicate to ensure clean processing
    df_clean = df.drop_duplicates(subset=['Entry']).copy()
    print(f"      Unique sequences to process: {len(df_clean)}")

    with open(fasta_path, 'w') as f_out:
        for _, row in df_clean.iterrows():
            seq_id = str(row['Entry']).strip().replace('|', '_')
            label = "global" 
            sequence = str(row['Sequence']).strip()
            f_out.write(f">{seq_id}|{label}\n{sequence}\n")
    
    return df_clean

def step_2_run_buggy_tool(fasta_path, out_dir):
    print(f"\n[2/4] Running fast_part.py (Output Train.fasta will break, this is expected)...")
    
    if os.path.exists(out_dir):
        shutil.rmtree(out_dir)

    # We assume fast_part.py is in the current directory
    cmd = [
        "python", "fast_part.py",
        "--fasta_file", fasta_path,
        "--output_dir", out_dir,
        "--method", METHOD,
        "--identity_threshold", str(IDENTITY_THRESHOLD),
        "--train_ratio", str(TRAIN_RATIO)
    ]

    try:
        subprocess.run(cmd, check=True)
    except subprocess.CalledProcessError:
        print("Error running fast_part.py")
        sys.exit(1)

def step_3_reconstruct_data(original_df, out_dir):
    print(f"\n[3/4] Reconstructing lost Training Data...")

    # 1. Get Test IDs (These are safe)
    test_fasta = os.path.join(out_dir, "Test.fasta")
    if not os.path.exists(test_fasta):
        print("CRITICAL: Test.fasta not found. The tool failed completely.")
        sys.exit(1)
        
    test_ids = set()
    for record in SeqIO.parse(test_fasta, "fasta"):
        test_ids.add(record.id.split('|')[0])
    
    # 2. Get Removed IDs (From Summary Log)
    summary_file = os.path.join(out_dir, "summary.txt")
    removed_ids = set()
    if os.path.exists(summary_file):
        with open(summary_file, 'r') as f:
            is_reading_ids = False
            for line in f:
                line = line.strip()
                if line == "Removed sequence IDs:":
                    is_reading_ids = True
                    continue
                if is_reading_ids and line:
                    # IDs in summary are just the ID (e.g., A0A510E346)
                    removed_ids.add(line)
    
    print(f"      Test Set Size:     {len(test_ids)}")
    print(f"      Removed Sequences: {len(removed_ids)}")

    # 3. Calculate Train IDs
    # Train = All - Test - Removed
    all_ids = set(original_df['Entry'].astype(str))
    
    # Filter valid Train IDs
    train_ids = all_ids - test_ids - removed_ids
    
    print(f"      Recovered Train Size: {len(train_ids)}")

    if len(train_ids) < 100:
        print("WARNING: Recovered Train set is still very small. Check threshold settings.")

    # 4. Create DataFrames
    test_df = original_df[original_df['Entry'].isin(test_ids)]
    train_df = original_df[original_df['Entry'].isin(train_ids)]
    
    return train_df, test_df

def step_4_save_outputs(train_df, test_df):
    print(f"\n[4/4] Saving final corrected CSVs...")
    train_df.to_csv(TRAIN_OUTPUT_CSV, index=False)
    test_df.to_csv(TEST_OUTPUT_CSV, index=False)
    print(f"      Success! Saved {TRAIN_OUTPUT_CSV} ({len(train_df)} rows)")
    print(f"      Success! Saved {TEST_OUTPUT_CSV} ({len(test_df)} rows)")

if __name__ == "__main__":
    if shutil.which("mmseqs") is None:
        print("Error: mmseqs not found in PATH.")
        sys.exit(1)

    if os.path.exists(INPUT_CSV):
        # Temp fasta for input
        temp_input = "temp_input_for_tool.fasta"
        
        # 1. Prepare
        df_clean = step_1_prepare_input(INPUT_CSV, temp_input)
        
        # 2. Run Tool (Let it fail on the file write)
        step_2_run_buggy_tool(temp_input, OUTPUT_DIR)
        
        # 3. Recover Data
        train_df, test_df = step_3_reconstruct_data(df_clean, OUTPUT_DIR)
        
        # 4. Save
        step_4_save_outputs(train_df, test_df)
        
        # Cleanup
        if os.path.exists(temp_input):
            os.remove(temp_input)
    else:
        print(f"Error: {INPUT_CSV} not found.")
# Out:
# [1/4] Reading and preparing halobacteriales_data.csv...
#       Unique sequences to process: 1103498
#
# [2/4] Running fast_part.py (Output Train.fasta will break, this is expected)...
# createdb fastpart_results/global/global.fasta fastpart_results/Temp/global_mmseq_db
#
# MMseqs Version:                    	18.8cc5c
# Database type                      	0
# Shuffle input database             	true
# Createdb mode                      	0
# Write lookup file                  	1
# Offset of numeric ids              	0
# Threads                            	8
# Compressed                         	0
# Mask residues                      	0
# Mask residues probability          	0.9
# Mask lower case residues           	0
# Mask lower letter repeating N times	0
# Use GPU                            	0
# Verbosity                          	3
#
# Converting sequences
# [===================================================================================================	1 Mio. sequences processed
# ==========
# Time for merging to global_mmseq_db_h: 0h 0m 0s 124ms
# Time for merging to global_mmseq_db: 0h 0m 0s 509ms
# Database type: Aminoacid
# Time for processing: 0h 0m 2s 227ms
# cluster fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_cluster fastpart_results/global/tmp --min-seq-id 0.3 -c 0.5 --cov-mode 1
#
# MMseqs Version:                     	18.8cc5c
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	4
# k-mer length                        	0
# Target search mode                  	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.5
# Coverage mode                       	1
# Compositional bias                  	1
# Compositional bias scale            	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Mask lower letter repeating N times 	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	8
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.3
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Weight file name
# Cluster Weight threshold            	0.9
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	false
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
#
# Set cluster sensitivity to -s 5.000000
# Set cluster mode GREEDY MEM
# Set cluster iterations to 3
# linclust fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/3396586329958143358/clu_redundancy fastpart_results/global/tmp/3396586329958143358/linclust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 0 --force-reuse 0
#
# kmermatcher fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.3 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# kmermatcher fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.3 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --cov-mode 1 -k 0 -c 0.5 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Database size: 1103498 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 1.10M 1s 971ms
# Sort kmer 0h 0m 0s 536ms
# Sort by rep. sequence 0h 0m 0s 287ms
# Time for fill: 0h 0m 0s 255ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 3s 438ms
# rescorediagonal fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 1.10M 0s 890ms
# Time for merging to pref_rescore1: 0h 0m 0s 237ms
# Time for processing: 0h 0m 1s 339ms
# clust fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref_rescore1 fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pre_clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 387ms
#
# Size of the sequence database: 1103498
# Size of the alignment database: 1103498
# Number of clusters: 311201
#
# Writing results 0h 0m 0s 44ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 523ms
# createsubdb fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/order_redundancy fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 95ms
# createsubdb fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/order_redundancy fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 117ms
# filterdb fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref_filter1 fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref_filter2 --filter-file fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/order_redundancy --threads 8 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 311.20K 0s 186ms
# Time for merging to pref_filter2: 0h 0m 0s 56ms
# Time for processing: 0h 0m 0s 317ms
# rescorediagonal fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref_filter2 fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.5 -a 0 --cov-mode 1 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 8 --compressed 0 -v 3
#
# [=================================================================] 311.20K 0s 141ms
# Time for merging to pref_rescore2: 0h 0m 0s 56ms
# Time for processing: 0h 0m 0s 317ms
# align fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pref_rescore2 fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 311201 type: Aminoacid
# Target database size: 311201 type: Aminoacid
# Calculation of alignments
# [=================================================================] 311.20K 1m 38s 652ms
# Time for merging to aln: 0h 0m 0s 66ms
# 791606 alignments calculated
# 697837 sequence pairs passed the thresholds (0.881546 of overall calculated)
# 2.242400 hits per query sequence
# Time for processing: 0h 1m 38s 816ms
# clust fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/aln fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/clust --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 67ms
#
# Size of the sequence database: 311201
# Size of the alignment database: 311201
# Number of clusters: 179469
#
# Writing results 0h 0m 0s 21ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 126ms
# mergeclusters fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/3396586329958143358/clu_redundancy fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/pre_clust fastpart_results/global/tmp/3396586329958143358/linclust/14134718762527647991/clust --threads 8 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 311.20K 0s 81ms
# Clustering step 2
# [=================================================================] 179.47K 0s 110ms
# Write merged clustering
# [=================================================================] 1.10M 0s 160ms
# Time for merging to clu_redundancy: 0h 0m 0s 36ms
# Time for processing: 0h 0m 0s 350ms
# createsubdb fastpart_results/global/tmp/3396586329958143358/clu_redundancy fastpart_results/Temp/global_mmseq_db fastpart_results/global/tmp/3396586329958143358/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 75ms
# prefilter fastpart_results/global/tmp/3396586329958143358/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3
#
# Query database size: 179469 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 179469 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 179.47K 0s 896ms
# Index table: Masked residues: 829845
# Index table: fill
# [=================================================================] 179.47K 0s 567ms
# Index statistics
# Entries:          16931311
# DB size:          585 MB
# Avg k-mer size:   0.264552
# Top 10 k-mers
#     HDRPVA	510
#     ENFNEH	447
#     GFVDPG	439
#     YVDGIP	350
#     RDTRRE	346
#     DGGPER	327
#     DGGGIV	326
#     NRLHRN	292
#     NLRAHG	289
#     GPGGTL	260
# Time for index table init: 0h 0m 1s 739ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 179469
# Target db start 1 to 179469
# [=================================================================] 179.47K 1s 655ms
#
# 1.457888 k-mers per position
# 435 DB matches per sequence
# 0 overflows
# 7 sequences passed prefiltering per query sequence
# 5 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 33ms
# Time for processing: 0h 0m 3s 927ms
# align fastpart_results/global/tmp/3396586329958143358/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/pref_step0 fastpart_results/global/tmp/3396586329958143358/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 179469 type: Aminoacid
# Target database size: 179469 type: Aminoacid
# Calculation of alignments
# [=================================================================] 179.47K 1m 37s 154ms
# Time for merging to aln_step0: 0h 0m 0s 34ms
# 1299418 alignments calculated
# 1013032 sequence pairs passed the thresholds (0.779604 of overall calculated)
# 5.644607 hits per query sequence
# Time for processing: 0h 1m 37s 302ms
# clust fastpart_results/global/tmp/3396586329958143358/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/aln_step0 fastpart_results/global/tmp/3396586329958143358/clu_step0 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 50ms
#
# Size of the sequence database: 179469
# Size of the alignment database: 179469
# Number of clusters: 96916
#
# Writing results 0h 0m 0s 11ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 85ms
# createsubdb fastpart_results/global/tmp/3396586329958143358/clu_step0 fastpart_results/global/tmp/3396586329958143358/input_step_redundancy fastpart_results/global/tmp/3396586329958143358/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 29ms
# prefilter fastpart_results/global/tmp/3396586329958143358/input_step1 fastpart_results/global/tmp/3396586329958143358/input_step1 fastpart_results/global/tmp/3396586329958143358/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 3 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3
#
# Query database size: 96916 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 96916 type: Aminoacid
# Index table k-mer threshold: 136 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 96.92K 0s 451ms
# Index table: Masked residues: 469282
# Index table: fill
# [=================================================================] 96.92K 0s 449ms
# Index statistics
# Entries:          17337279
# DB size:          587 MB
# Avg k-mer size:   0.270895
# Top 10 k-mers
#     HDRPVA	131
#     GFVDPG	118
#     ENFNEH	112
#     RRLAGA	107
#     RRLAAA	101
#     RDTRRE	97
#     AAGAAG	89
#     ASVHRN	84
#     DGGGIV	82
#     FGVAAL	80
# Time for index table init: 0h 0m 1s 244ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 136
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 96916
# Target db start 1 to 96916
# [=================================================================] 96.92K 3s 329ms
#
# 15.636439 k-mers per position
# 1152 DB matches per sequence
# 0 overflows
# 9 sequences passed prefiltering per query sequence
# 7 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 19ms
# Time for processing: 0h 0m 5s 52ms
# align fastpart_results/global/tmp/3396586329958143358/input_step1 fastpart_results/global/tmp/3396586329958143358/input_step1 fastpart_results/global/tmp/3396586329958143358/pref_step1 fastpart_results/global/tmp/3396586329958143358/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 96916 type: Aminoacid
# Target database size: 96916 type: Aminoacid
# Calculation of alignments
# [=================================================================] 96.92K 15s 703ms
# Time for merging to aln_step1: 0h 0m 0s 22ms
# 697125 alignments calculated
# 226889 sequence pairs passed the thresholds (0.325464 of overall calculated)
# 2.341089 hits per query sequence
# Time for processing: 0h 0m 15s 827ms
# clust fastpart_results/global/tmp/3396586329958143358/input_step1 fastpart_results/global/tmp/3396586329958143358/aln_step1 fastpart_results/global/tmp/3396586329958143358/clu_step1 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 17ms
#
# Size of the sequence database: 96916
# Size of the alignment database: 96916
# Number of clusters: 70161
#
# Writing results 0h 0m 0s 7ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 38ms
# createsubdb fastpart_results/global/tmp/3396586329958143358/clu_step1 fastpart_results/global/tmp/3396586329958143358/input_step1 fastpart_results/global/tmp/3396586329958143358/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 21ms
# prefilter fastpart_results/global/tmp/3396586329958143358/input_step2 fastpart_results/global/tmp/3396586329958143358/input_step2 fastpart_results/global/tmp/3396586329958143358/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 5 -k 0 --target-search-mode 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.5 --cov-mode 1 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --mask-n-repeat 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 8 --compressed 0 -v 3
#
# Query database size: 70161 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 70161 type: Aminoacid
# Index table k-mer threshold: 118 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 70.16K 0s 337ms
# Index table: Masked residues: 351422
# Index table: fill
# [=================================================================] 70.16K 0s 327ms
# Index statistics
# Entries:          12948677
# DB size:          562 MB
# Avg k-mer size:   0.202323
# Top 10 k-mers
#     RRLAAA	80
#     AAAAAA	71
#     AVAAAA	66
#     LAAALA	65
#     ALAAAL	64
#     LALVLV	63
#     AAAALA	62
#     AAALLA	62
#     ALAAAV	62
#     VALALA	61
# Time for index table init: 0h 0m 0s 942ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 118
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 70161
# Target db start 1 to 70161
# [=================================================================] 70.16K 10s 188ms
#
# 121.169417 k-mers per position
# 6236 DB matches per sequence
# 0 overflows
# 17 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 17ms
# Time for processing: 0h 0m 11s 637ms
# align fastpart_results/global/tmp/3396586329958143358/input_step2 fastpart_results/global/tmp/3396586329958143358/input_step2 fastpart_results/global/tmp/3396586329958143358/pref_step2 fastpart_results/global/tmp/3396586329958143358/aln_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.3 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.5 --cov-mode 1 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 8 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 70161 type: Aminoacid
# Target database size: 70161 type: Aminoacid
# Calculation of alignments
# [=================================================================] 70.16K 9s 500ms
# Time for merging to aln_step2: 0h 0m 0s 12ms
# 791599 alignments calculated
# 110713 sequence pairs passed the thresholds (0.139860 of overall calculated)
# 1.577985 hits per query sequence
# Time for processing: 0h 0m 9s 560ms
# clust fastpart_results/global/tmp/3396586329958143358/input_step2 fastpart_results/global/tmp/3396586329958143358/aln_step2 fastpart_results/global/tmp/3396586329958143358/clu_step2 --cluster-mode 3 --max-iterations 1000 --similarity-type 2 --threads 8 --compressed 0 -v 3 --cluster-weight-threshold 0.9
#
# Clustering mode: Greedy Low Mem
# Total time: 0h 0m 0s 9ms
#
# Size of the sequence database: 70161
# Size of the alignment database: 70161
# Number of clusters: 57545
#
# Writing results 0h 0m 0s 6ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 23ms
# mergeclusters fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_cluster fastpart_results/global/tmp/3396586329958143358/clu_redundancy fastpart_results/global/tmp/3396586329958143358/clu_step0 fastpart_results/global/tmp/3396586329958143358/clu_step1 fastpart_results/global/tmp/3396586329958143358/clu_step2 --threads 8 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 179.47K 0s 59ms
# Clustering step 2
# [=================================================================] 96.92K 0s 75ms
# Clustering step 3
# [=================================================================] 70.16K 0s 85ms
# Clustering step 4
# [=================================================================] 57.54K 0s 91ms
# Write merged clustering
# [=================================================================] 1.10M 0s 142ms
# Time for merging to global_mmseq_cluster: 0h 0m 0s 11ms
# Time for processing: 0h 0m 0s 287ms
# createtsv fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_db fastpart_results/Temp/global_mmseq_cluster fastpart_results/Temp/global_mmseq.tsv
#
# MMseqs Version:                 	18.8cc5c
# First sequence as representative	false
# Target column                   	1
# Add full header                 	false
# Sequence source                 	0
# Database output                 	false
# Threads                         	8
# Compressed                      	0
# Verbosity                       	3
#
# Time for merging to global_mmseq.tsv: 0h 0m 0s 30ms
# Time for processing: 0h 0m 0s 233ms
# diamond v2.1.16.170 (C) Max Planck Society for the Advancement of Science, Benjamin J. Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 8
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database input file: fastpart_results/Temp/train.fasta
# Opening the database file...  [0.001s]
# Loading sequences...  [2.264s]
# Masking sequences...  [1.869s]
# Writing sequences...  [0.1s]
# Hashing sequences...  [0.074s]
# Loading sequences...  [0s]
# Writing trailer...  [0.006s]
# Closing the input file...  [0s]
# Closing the database file...  [0.001s]
#
# Database sequences  882928
#   Database letters  255348542
#      Database hash  64bda5be7154ad986a750dd72b460343
#         Total time  4.319000s
# diamond v2.1.16.170 (C) Max Planck Society for the Advancement of Science, Benjamin J. Buchfink, University of Tuebingen
# Documentation, support and updates available at http://www.diamondsearch.org
# Please cite: http://dx.doi.org/10.1038/s41592-021-01101-x Nature Methods (2021)
#
# #CPU threads: 8
# Scoring parameters: (Matrix=BLOSUM62 Lambda=0.267 K=0.041 Penalties=11/1)
# Database input file: fastpart_results/Train.fasta
# Opening the database file...  [0.012s]
# Loading sequences...  [2.361s]
# Masking sequences...  [1.993s]
# Writing sequences...  [0.12s]
# Hashing sequences...  [0.071s]
# Loading sequences...  [0s]
# Writing trailer...  [0.006s]
# Closing the input file...  [0s]
# Closing the database file...  [0s]
#
# Database sequences  882928
#   Database letters  255348542
#      Database hash  64bda5be7154ad986a750dd72b460343
#         Total time  4.566000s
# Updated combined train file is saved to fastpart_results/Train.fasta
# Updated combined test file is saved to fastpart_results/Test.fasta
# Summary file is saved to fastpart_results/summary.txt
# Execution time: 586.51 seconds
#
# [3/4] Reconstructing lost Training Data...
#       Test Set Size:     220570
#       Removed Sequences: 114882
#       Recovered Train Size: 768051
#
# [4/4] Saving final corrected CSVs...
#       Success! Saved halobacteriales_train.csv (768051 rows)
#       Success! Saved halobacteriales_test.csv (220570 rows)
